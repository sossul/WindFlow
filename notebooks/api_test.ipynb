# %%
# !curl -X POST -d 'username=apicodelco&password=codelco.,2022' https://airviro.r9.cl/api/v2/auth.cgi
# Out:
# { "data": { "authenticator": "GB5kGVlq8sTCDYPbszEbqFkZAjw94j53Ykk+AaX+KLjsHnCRPX5q0", "unixtime": 1665583201, "server-time": "2022-10-12 10:00:01 -04", "timezone": "Etc/GMT+4" }, "links": { "self": "https://airviro.r9.cl/api/auth.cgi" } }

# %%
import json
import requests

url = "https://airviro.r9.cl/api/v2/auth.cgi"
x = requests.post(url, auth = ('apicodelco', 'codelco.,2022'))
x.json()
# Out:
# {'errors': [{'status': '403 Forbidden', 'title': 'Authentication failure.'}]}

# %%
import json
import requests

url_auth = "https://airviro.r9.cl/api/v2/auth.cgi"
data = {'username':'apicodelco',
        'password':'codelco.,2022'}
r_auth = requests.post(url_auth, data=data)
headers = {'authenticator':r_auth.json()['data']['authenticator']}
r_auth.json()
# Out:
# {'data': {'authenticator': 'WnuZ0wylZbi6EOCaa1DUf+E8=HBD8qre9zl=7gTlDJ7uY9SQ4PeL0',
#   'unixtime': 1665583203,
#   'server-time': '2022-10-12 10:00:03 -04',
#   'timezone': 'Etc/GMT+4'},
#  'links': {'self': 'https://airviro.r9.cl/api/auth.cgi'}}

# %%
# !curl -X GET "https://airviro.r9.cl/api/v1/domain/CODELCO" \
     -H 'Authenticator: K1ykGBjKDDWzAnVfYa2Lahs24_4_uyptAeaq83I98gIa73-e5rxw0' \
     -H 'Content-Type: application/x-www-form-urlencoded; charset=utf-8' \
     -H 'Cookie: SESSID=OFYZH_xi5nyXFYtgDxWn9XUXDZO7bHqF7aXLFDOo3UVROa2LDuqV0' \
     --data-urlencode "username=apicodelco" \
     --data-urlencode "password=codelco.,2022"
# Out:
# {"data":{"resolution":{"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO/resolution"}},"station":{"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO/station"}},"parameter":{"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO/parameter"}},"timeserie":{"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO/timeserie"}},"macro":{"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO/macro"}}},"meta":{"copyright":"Copyright 2021 R9 Ingenieria Spa.","authors":[{"fullname":"Nelson Hereveri","email":"nh@r9.cl"}]},"links":{"self":"https://airviro.r9.cl/api/v1/domain/CODELCO"}}

# %%
c
# Out:
# {'data': {'timeserie': [{'timestamp': 1565876580,
#     'value': 9.77,
#     'statusCode': 14},
#    {'timestamp': 1565876640, 'value': 3.754, 'statusCode': 14},
#    {'timestamp': 1565876700, 'value': 6.67, 'statusCode': 14},
#    {'timestamp': 1565876760, 'value': 7.359, 'statusCode': 14},
#    {'timestamp': 1565876820, 'value': 6.073, 'statusCode': 14},
#    {'timestamp': 1565876880, 'value': 7.624, 'statusCode': 14},
#    {'timestamp': 1565876940, 'value': 9.78, 'statusCode': 14},
#    {'timestamp': 1565877000, 'value': 7.724, 'statusCode': 14},
#    {'timestamp': 1565877060, 'value': 4.733, 'statusCode': 14},
#    {'timestamp': 1565877120, 'value': 6.492, 'statusCode': 14},
#    {'timestamp': 1565877180, 'value': 8.18001, 'statusCode': 14},
#    {'timestamp': 1565877240, 'value': 4.84, 'statusCode': 14},
#    {'timestamp': 1565877300, 'value': 6.769, 'statusCode': 14},
#    {'timestamp': 1565877360, 'value': 9.28999, 'statusCode': 14},
# ...

# %%
import requests

headers = {
    'Authenticator': 'K1ykGBjKDDWzAnVfYa2Lahs24_4_uyptAeaq83I98gIa73-e5rxw0',
    'Content-Type': 'application/x-www-form-urlencoded; charset=utf-8',
     'Cookie': 'SESSID=OFYZH_xi5nyXFYtgDxWn9XUXDZO7bHqF7aXLFDOo3UVROa2LDuqV0',
}

data = 'username=apicodelco&password=codelco.,2022'
params = {'username':'apicodelco',
        'password':'codelco.,2022'}

response = requests.get('https://airviro.r9.cl/api/v1/domain/CODELCO', headers=headers, data=params)
response.json()

# %%
import requests
headers = {
    'Authenticator': 'K1ykGBjKDDWzAnVfYa2Lahs24_4_uyptAeaq83I98gIa73-e5rxw0',
    'Content-Type': 'application/x-www-form-urlencoded; charset=utf-8',
    'Cookie': 'SESSID=OFYZH_xi5nyXFYtgDxWn9XUXDZO7bHqF7aXLFDOo3UVROa2LDuqV0',
}
params = {'username':'apicodelco',
        'password':'codelco.,2022'}

response = requests.get('https://airviro.r9.cl/api/v2/domain/CODELCO/timeserie/GAA,MSTWD010/1665491340/1665577680/', headers=headers)
response.json()

# %%
url = 'https://airviro.r9.cl/api/v2/domain/CODELCO/timeserie/GAA,MSTWD010/1665491340/1665577680/'
header = {'Authenticator: K1ykGBjKDDWzAnVfYa2Lahs24_4_uyptAeaq83I98gIa73-e5rxw0',
          'Content-Type: application/x-www-form-urlencoded; charset=utf-8' \
     -H 'Cookie: SESSID=OFYZH_xi5nyXFYtgDxWn9XUXDZO7bHqF7aXLFDOo3UVROa2LDuqV0'}
requests.post(url_auth, headers={"Content-Type":"text"}a)

# %%
url = 'https://airviro.r9.cl/api/v2/domain/CODELCO/timeserie/GAA,MSTWD010/1665491340/1665577680/'
r_auth = requests.post(url_auth, data=data)
headers = {'authenticator': 'GVxnmckLApLzA4U9ZP9Ko2wU4Lh89IR-Se13w-7wWxzaPpooYApq0'}
auth_response = requests.get(url, headers=headers)
auth_response.json()

# %%
headers = {'authenticator': 'sLz6RfIeUqef6nQbtwGcitqEzQE8wbLo3eiwOjz9btS1lD4xtx=a0'}
r = requests.get('https://r9.cl/api/domain/CODELCO/resolution', headers=headers, verify=False)
r

# %%
# Authenticating with OAuth2 in Requests
from requests_oauthlib import OAuth2Session

client_id = "apicodelco"
client_secret = "codelco.,2022"
#redirect_uri = "include your redirect URI here"
# Create a session object
oauth = OAuth2Session(client_id)

token = oauth.fetch_token("https://airviro.r9.cl/api/v2/auth.cgi", client_secret = client_secret)



# Get your authenticated response
resp = oauth.get("https://r9.cl/api/domain/CODELCO")

resp

# %%
url = 'https://r9.cl/api/'
r = requests.get(url, headers=auth)
r.json()

# %%
url = 'https://r9.cl/api/domain/CODELCO'
#domain= 'CODELCO'

requests.get(url)
